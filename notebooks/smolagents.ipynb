# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel

agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=HfApiModel())

agent.run("How many seconds would it take for a horse running at full speed to run the length of O'Connel Street in Dublin?")
# Out:
# ╭────────────────────────────────────────────────────────────────────────────────────────────── New run ───────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                                                                                      │
# │ How many seconds would it take for a horse running at full speed to run the length of O'Connel Street in Dublin?                                                                                     │
# │                                                                                                                                                                                                      │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 0 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─ Executing this code: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │   1 length_query = "Length of O'Connell Street Dublin"                                                                                                                                               │
# │   2 length_results = web_search(query=length_query)                                                                                                                                                  │
# │   3 print(length_results)                                                                                                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Execution logs:
# ## Search Results
#
# [O'Connell Street - Wikipedia](https://en.wikipedia.org/wiki/O'Connell_Street)
# O'Connell Street is located on the north side of Dublin city, and runs northwards from O'Connell Bridge towards Parnell Square.The street is approximately 1,980 feet (600 m) long and 150 feet (46 m)
# wide, with two broad carriageways at either side of a central pathway occupied by various monuments and statues. [1] It has previously been part of the N1, a major road from Dublin to Belfast.
#
# [The General Post Office, O'Connell Street, Dublin 1 - Buildings of Ireland](https://www.buildingsofireland.ie/building-of-the-month/the-general-post-office-oconnell-street-dublin-1/)
# The General Post Office (GPO) in O'Connell Street, Dublin, ... 223 feet in length, 150 feet in depth, and three stories high. In the centre of the front is a boldly projecting portico of six fluted
# Ionic columns supporting an entablature and cornice, which are continued round the building and surmounted by a triangular pediment, and on the ...
#
# [GPS coordinates of O'Connell Street, Ireland - Latitude.to](https://latitude.to/articles-by-country/ie/ireland/9457/oconnell-street)
# O'Connell Street (Irish: Sráid Uí Chonaill) is Dublin's main thoroughfare.It measures 49 m (160 ft) in width at its southern end, 46 m (150 ft) at the north, and is 500 m (1650 ft) in length. During
# the 17th century it was a narrow street known as Drogheda Street (named after Henry Moore, Earl of Drogheda).
#
# [O'Connell Street, Dublin, Ireland Tourist Information](https://www.touristlink.com/ireland/oconnell-street/overview.html)
# O'Connell Street is Dublin's main thoroughfare. It measures 49 m (160 ft) in width at its southern end, 46 m (150 ft) at the north, and is 500 m (1650 ft) in length. Known as 'Sackville Street' until
# 1924, it was renamed in honour of Daniel O'Connell, a nationalist leader of the early nineteenth century whose statue stands at the lower end of the street, facing O'Connell Bridge.
#
# [O'Connell Street facts for kids - Kids encyclopedia](https://kids.kiddle.co/O'Connell_Street)
# Location. O'Connell Street is located on the north side of Dublin city, and runs northwards from O'Connell Bridge towards Parnell Square.The street is approximately 1,980 feet (600 m) long and 150
# feet (46 m) wide, with two broad carriage ways at either side of a central pathway occupied by various monuments and statues.
#
# [Is O Connell street the widest in Europe? - Geographic Pedia - NCESC](https://www.ncesc.com/geographic-pedia/is-o-connell-street-the-widest-in-europe/)
# Nevertheless, O'Connell Street remains an architectural masterpiece and a must-visit destination in Dublin. Stretching 500 meters in length and up to 49 meters in width, this grand boulevard
# captivates visitors with its imposing statues of Irish historical figures that line the central median. ... What was the old name for O'Connell Street ...
#
# [O'Connell Street - castle-hotel.ie](https://www.castle-hotel.ie/directory-entry/oconnell-street)
# O'Connell Street is one of Dublin's main streets in the heart of the City. The street is one of the widest streets in Europe. It measures around 49 metres (160 ft) in width and 500 metres (1650 ft) in
# length. Until 1924 O'Connell St the street was known as 'Sackville Street'.
#
# [O'Connell Street - Dublin's famous main street](https://www.introducingdublin.com/oconnell-street)
# O'Connell Street Monuments. O'Connell Street houses numerous sculptures and monuments, including one of the world's tallest sculptures called The Spire, a large needle-like monument that stands 120
# meters (393 feet) high. The Spire was designed in 2003 and placed where Nelson's Pillar once stood, destroyed years earlier by the IRA ...
#
# [O'Connell Street, Dublin, Ireland - planergo.com](https://planergo.com/en/sights/OConnell-Street/)
# O'Connell Street (Irish: Sráid Uí Chonaill) is Dublin's main thoroughfare. It measures 49 m (160 ft) in width at its southern end, 46 m (150 ft) at the north, and is 500 m (1650 ft) in length. Known
# as 'Sackville Street' until 1924, it was renamed in honour of Daniel O'Connell, a nationalist leader of the early nineteenth century whose statue stands at the lower end of the street, facing O ...
#
# [O' Connell Street Map - Bus stop - Dublin, Ireland - Mapcarta](https://mapcarta.com/35991154)
# O' Connell Street is a bus stop in Dublin, Leinster. O' Connell Street is situated nearby to Spire of Dublin, as well as near General Post Office. Overview: Map: Directions: ... St Mary's
# Pro-Cathedral is situated 170 metres northeast of O' Connell Street. Locales in the Area. Temple Bar. Quarter Photo: ...
#
# Out: None
# [Step 0: Duration 6.52 seconds| Input tokens: 2,083 | Output tokens: 158]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─ Executing this code: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │   1 speed_query = "Top speed of a horse"                                                                                                                                                             │
# │   2 speed_results = web_search(query=speed_query)                                                                                                                                                    │
# │   3 print(speed_results)                                                                                                                                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Execution logs:
# ## Search Results
#
# [Top 7 Fastest Horses of All Time - Horsey Hooves](https://horseyhooves.com/fastest-horses/)
# Learn about the record-breaking speed of these legendary racehorses, from Secretariat to Winning Brew. Find out their achievements, earnings, and how they became icons of the equine industry.
#
# [The 8 Fastest Horse Breeds In The World & Their Top Speeds](https://www.horsefactbook.com/breeds/worlds-fastest-horses/)
# Learn about the eight fastest horse breeds in the world and their top speeds for different types of racing. Find out how speed matters for horses and their history and characteristics.
#
# [How Fast Can a Horse Run? Fastest Horses in History - Horsey Hooves](https://horseyhooves.com/how-fast-can-a-horse-run/)
# Learn about the average and record speeds of different horse breeds and gaits, and how they evolved to run fast. Find out which horse is the fastest ever and how to measure horse speed.
#
# [10 Fastest Horse Breeds in the World - Horsey Hooves](https://horseyhooves.com/fastest-horse-breeds/)
# Learn about the top speed of different horse breeds, from Quarter Horses to Arabians. Find out how they evolved, what they are used for, and how they compare to other animals.
#
# [How Fast Can A Horse Run? Top Speeds, Fastest Breeds, and More](https://insiderhorse.com/how-fast-can-a-horse-run/)
# Learn about the fastest gallop ever recorded, the breeds that can run the fastest, and the factors that affect a horse's speed. Find out how horses run on the flat or over jumps, and who is the
# fastest trotting horse in the world.
#
# [Top 9 Fastest Horses - A-Z Animals](https://a-z-animals.com/animals/horse/horse-facts/fastest-horses/)
# This article will cover the top nine fastest horse breeds in the world. Top speed will be the main factor, but so will stamina and endurance over long distances. Many of the horses on this list are
# "hot-blooded." This means the breed combines excellent speed and agility with a bold and spirited temperament. 9: Mustang
#
# [How Fast Can Horses Run? Top Breeds, Record Speeds & Performance ...](https://madbarn.com/how-fast-can-horses-run/)
# Maximum Horse Speed. The current world record for fastest horse speed is approximately 44 miles per hour (71 km/h). This speed was achieved by a thoroughbred named Winning Brew, who set the record at
# the Penn National Race Course in 2008. With that being said, the maximum achievable speed of a horse is relative to the total distance travelled.
#
# [Fastest Horses In History: Racing Legends & Their Records](https://horseracingsense.com/speed-worlds-fastest-horses-in-history/)
# Winning Brew, a remarkable Thoroughbred, etched his name in the Guinness World Records by achieving a top speed of 43.97 mph in 2008. This feat cemented his place as the fastest horse ever recorded.
# ... rigorous training and conditioning are essential for maximizing a horse's speed. Training methods have evolved throughout history ...
#
# [How Fast Can a Horse Run? Fastest Horses Ever](https://www.willowbrookridingcentre.co.uk/how-fast-can-a-horse-run/)
# A more comprehensive study, "Racing Speeds of Quarter Horses, Thoroughbreds, and Arabians," was published in the Equine Veterinary Journal in 2006.Led by Dr Brian Nielsen of Michigan State University,
# this research used a larger dataset of race results. It recorded a top speed of 57.6 miles per hour (92.6 kilometers per hour) for Quarter Horses in the final stretch of a 302 meter race.
#
# [The 10 Fastest Horse Breeds in the World - OwnTheHorse](https://ownthehorse.com/fastest-horse-breeds-in-the-world/)
# Welcome to our guide on the top 10 fastest horse breeds in the world. There are many different horse breeds in the world, each with their own unique. ... In conclusion, the Akhal-Teke is a remarkable
# breed of horse that is known for its speed, endurance, and athleticism. They have a unique appearance and are highly sought after for showjumping ...
#
# Out: None
# [Step 1: Duration 5.18 seconds| Input tokens: 5,655 | Output tokens: 249]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─ Executing this code: ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │    1 # Constants                                                                                                                                                                                     │
# │    2 length_of_street_meters = 500  # Length of O'Connell Street in meters                                                                                                                           │
# │    3 horse_speed_mph = 44  # Top speed of a horse in miles per hour                                                                                                                                  │
# │    4                                                                                                                                                                                                 │
# │    5 # Conversion factors                                                                                                                                                                            │
# │    6 miles_to_meters = 1609.34  # 1 mile = 1609. 34 meters                                                                                                                                           │
# │    7 hours_to_seconds = 3600  # 1 hour = 3600 seconds                                                                                                                                                │
# │    8                                                                                                                                                                                                 │
# │    9 # Convert speed from mph to m/s                                                                                                                                                                 │
# │   10 horse_speed_mps = horse_speed_mph * miles_to_meters / hours_to_seconds                                                                                                                          │
# │   11                                                                                                                                                                                                 │
# │   12 # Calculate time in seconds                                                                                                                                                                     │
# │   13 time_seconds = length_of_street_meters / horse_speed_mps                                                                                                                                        │
# │   14 final_answer(time_seconds)                                                                                                                                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Out - Final answer: 25.41979377203755
# [Step 2: Duration 10.08 seconds| Input tokens: 10,327 | Output tokens: 515]
# 25.41979377203755
